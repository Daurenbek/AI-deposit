# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dep = pd.read_csv("demo/Assignment2.csv", sep = ";")

# %%
dep
# Out:
#                        Name  Age  Gender Marital status Education degree  \
# 0          Abdurasil Dinara   21  female         single         bechelor
# 1      Abdizhapbar Gaukhar    21  female         single         bachelor
# 2              Abilova Mira   20  female         single         bechelor
# 3                Adil Amina   18  female         single         bechelor
# 4              Adil Amelina   23  female        married         bachelor
# 5                 Adil Aset   25    Male         single         bachelor
# 6              Akhan Moldir   22  female         single         bachelor
# 7            Akhan Moldiyar   24    Male        married         bachelor
# 8             Akhan Madiyar   29    Male        married         bachelor
# 9             Akhan Aldiyar   32   male         married           master
# 10        Akhmetova Ayazhan   35  female         single              Phd
# 11       Akhmetov Beibarys    38    male        married        secondary
# ...

# %% [markdown]
# Using this type of function, we display in python all the numerical and non-numerical information contained in the file. Here, as a rule, I show the number of columns and rows.
# Using this method, DataFrame.loc python takes 5 start and last information, columns and rows from a dataset. By setting a certain number, or rather specifying it in a real amount, we can display the rows and columns we need. The 'sep' function by default. used to change lines in order to add a separator

# %%
dep.head()
# Out:
#                    Name  Age  Gender Marital status Education degree  \
# 0      Abdurasil Dinara   21  female         single         bechelor
# 1  Abdizhapbar Gaukhar    21  female         single         bachelor
# 2          Abilova Mira   20  female         single         bechelor
# 3            Adil Amina   18  female         single         bechelor
# 4          Adil Amelina   23  female        married         bachelor
#
#           Job  Estate property Deposit property Loan property  \
# 0  unemployed  has real estate       no deposit       no loan
# 1    employed        no estate      has deposit       no loan
# 2  unemployed  has real estate      has deposit       no loan
# 3  unemployed  has real estate      has deposit       no loan
# 4    employed  has real estate       no deposit       no loan
#
#    Number of children
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   2

# %% [markdown]
# Using this type of function, we display in python all the numerical and non-numerical information contained in the file. Here, as a rule, I show the number of columns and rows.
# Using this method, DataFrame.loc python takes 5 start and last information, columns and rows from a dataset. By setting a certain number, or rather specifying it in a real amount, we can display the rows and columns we need. The 'sep' function by default. used to change lines in order to add a separator

# %%
dep.tail()
# Out:
#                     Name  Age  Gender Marital status Education degree  \
# 98   Zhumadilova Aigerim   37  female        married        secondary
# 99   Zhumadilova Aishat    34  female       married          bechelor
# 100  Zhumadilova Aiganym   28  female       married          bachelor
# 101   Zhumadilova Ardak    28  female        married         bechelor
# 102     Zhumadilov Aizak   33    male        married         bachelor
#
#             Job  Estate property Deposit property Loan property  \
# 98     employed  has real estate      has deposit       no loan
# 99   unemployed  has real estate       no deposit       no loan
# 100  unemployed        no estate       no deposit       no loan
# 101    employed  has real estate       no deposit       no loan
# 102    employed  has real estate      has deposit       no loan
#
#      Number of children
# 98                    3
# 99                    4
# 100                   3
# 101                   0
# 102                   1

# %% [markdown]
# Using this type of function, we display in python all the numerical and non-numerical information contained in the file. Here, as a rule, I show the number of columns and rows.
# Using this method, DataFrame.loc python takes 5 start and last information, columns and rows from a dataset. By setting a certain number, or rather specifying it in a real amount, we can display the rows and columns we need. The 'sep' function by default. used to change lines in order to add a separator

# %%
dep.tail(2)
# Out:
#                    Name  Age  Gender Marital status Education degree  \
# 101  Zhumadilova Ardak    28  female        married         bechelor
# 102    Zhumadilov Aizak   33    male        married         bachelor
#
#           Job  Estate property Deposit property Loan property  \
# 101  employed  has real estate       no deposit       no loan
# 102  employed  has real estate      has deposit       no loan
#
#      Number of children
# 101                   0
# 102                   1

# %% [markdown]
# As we said above, indicating the number, you can get other information, more shortened or vice versa. and here we observe that n (2) is indicated here.

# %%
dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
# Name                  103 non-null object
# Age                   103 non-null int64
# Gender                103 non-null object
# Marital status        103 non-null object
# Education degree      103 non-null object
# Job                   103 non-null object
# Estate property       103 non-null object
# Deposit property      103 non-null object
# Loan property         103 non-null object
# Number of children    103 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 8.1+ KB

# %% [markdown]
# Order to get a short overview of the dataset, we use this kind of function, since our dataset includes a lot of information. Here we point to an immutable value, which provides integers with the value of a negative object or a positive object, and it is 64 bit data. This means that the function works only because the python uses a special mechanism or structure.

# %%
dep.shape
# Out:
# (103, 10)

# %% [markdown]
# By this function, can we get a measure of the dataset? which is shown as columns and rows

# %%
dep.corr(method = "pearson")
# Out:
#                          Age  Number of children
# Age                 1.000000            0.679005
# Number of children  0.679005            1.000000

# %% [markdown]
# By this method of correlation we find the relationship between the attributes. The numbers indicate the correlation of two variables. Since their range is between -1 and 1, and from -1 to 0. we can determine whether it is negative or positive. If we have indicated a positive correlation, then we can safely say that if one of them grows, then the second grows, also in negative correlation, only with the reduction method. and here a positive correlation is indicated at 0.68 which is significant.

# %%
dep.corr(method = 'kendall')
# Out:
#                          Age  Number of children
# Age                 1.000000            0.644948
# Number of children  0.644948            1.000000

# %% [markdown]
# This correlation, is a function which is used to identify the ordinal association between two measured objects. There the correlation number is on intersection of age and N.of.ch.
#
# It is important to note that "pearson method" needs just to take numbers while "Kendall method" represents the similarities between variables.

# %%
dep.corr(method = 'spearman')
# Out:
#                          Age  Number of children
# Age                 1.000000            0.771433
# Number of children  0.771433            1.000000

# %% [markdown]
# Using the spearman method, the function selects the actual choices and gives the correlation coefficient also in the range from -1 to 1. And having learned the value, we can display the significance of the coefficient. And according to our data, it is significant. here we can see the difference between pearson and spearman. since pearson usually defines data, and spearman makes no assumptions about data distribution

# %%
dep.describe()
# Out:
#               Age  Number of children
# count  103.000000          103.000000
# mean    30.757282            1.291262
# std     13.616934            1.563249
# min     18.000000            0.000000
# 25%     21.000000            0.000000
# 50%     26.000000            0.000000
# 75%     35.000000            3.000000
# max     81.000000            5.000000

# %% [markdown]
# The line "count", reveals to us the quantity of lines of each item, the quantity of lines.
#
# Mean is the average age of individuals, the number of kids for our situation. Likewise, the standard deviation for every segment (age, number of kids) is a pointer of the quantity of changes or scattering of these capacities. It likewise shows just numerical information. In fund, st.dev involves a significant spot since it was utilized to decide the standard. Commonly, SEM goes astray less from St.Dev. What's more, the date on the set shows extraordinary significance among them. since we did the overview from 18 to 81. The normal worth is the normal estimation of the whole informational collection accessible to the specialist or organizations. In this manner, the standard deviation and the mean worth assume an essential job so as to comprehend our data and demonstrate focuses from the above information.

# %%
dep.describe(include=np.object)
# Out:
#                 Name  Gender Marital status Education degree       Job  \
# count            103     103            103              103       103
# unique           103       4              3                5         2
# top     Kasen Aiman   female         single         bachelor  employed
# freq               1      53             52               45        70
#
#         Estate property Deposit property Loan property
# count               103              103           103
# unique                2                2             2
# top     has real estate      has deposit       no loan
# freq                 67               57            79

# %% [markdown]
# These functions show basic statistics for numerical inflation. describe () it does not calculate the mean or standard deviation value for the information since in the majority in the dataset the content is texts. Despite this, it shows a minimum of statistical explanations.  but using the include function we can show other data types

# %%
dep.axes
# Out:
# [RangeIndex(start=0, stop=103, step=1),
#  Index(['Name', 'Age', 'Gender', 'Marital status', 'Education degree', 'Job',
#         'Estate property', 'Deposit property', 'Loan property',
#         'Number of children'],
#        dtype='object')]
